# %%
name="krish"

age = 19

CGPA=7.6

Placed=True

print("Student name:", name)

print ("Age:", age)

print("CGPA:", CGPA)

print("Placed:", Placed)

print (type (name))
# Out:
# Student name: krish
# Age: 19
# CGPA: 7.6
# Placed: True
# <class 'str'>
